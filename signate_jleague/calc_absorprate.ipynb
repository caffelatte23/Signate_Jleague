# %%
import pandas as pd

# %%
train = pd.read_csv('./data/total_train.csv')
stadium = pd.read_csv('./data/moto/stadium.csv')

# %%
train.drop(1567,axis=0,inplace=True)
absorp = pd.merge(left=train,right=stadium,left_on='stadium',right_on='name')

# %%
# absorp = train.groupby(['year','stadium'])['y'].mean()

# %%
absorp.to_csv('./data/absorp4.csv',index=False)

# %%
absorp = pd.read_csv('./data/absorp4.csv')

# %%
absorp['absorp'] = round((absorp['y']/absorp['capa'])*100 , 2)

# %%
absorp
# Out:
#          id      y  year stage    match   gameday   time      home       away  \
# 0     13994  18250  2012    Ｊ１   第１節第１日  03/10(土)  14:04    ベガルタ仙台   鹿島アントラーズ
# 1     14012  11831  2012    Ｊ１   第３節第１日  03/24(土)  13:03    ベガルタ仙台  大宮アルディージャ
# 2     14031  13147  2012    Ｊ１   第５節第１日  04/07(土)  14:03    ベガルタ仙台     ジュビロ磐田
# 3     14055  17192  2012    Ｊ１   第７節第１日  04/21(土)  19:04    ベガルタ仙台       ＦＣ東京
# 4     14075  18525  2012    Ｊ１  第１０節第１日  05/06(日)  13:04    ベガルタ仙台    清水エスパルス
# ...     ...    ...   ...   ...      ...       ...    ...       ...        ...
# 1946  16137   2772  2014    Ｊ２  第１５節第１日  05/24(土)  19:03  カマタマーレ讃岐     カターレ富山
# 1947  16157   2626  2014    Ｊ２  第１７節第１日  06/07(土)  16:03  カマタマーレ讃岐   コンサドーレ札幌
# 1948  16178   1921  2014    Ｊ２  第１９節第１日  06/21(土)  18:03  カマタマーレ讃岐   モンテディオ山形
# 1949  16188   2328  2014    Ｊ２  第２０節第１日  06/28(土)  18:03  カマタマーレ讃岐  水戸ホーリーホック
# 1950  16220   3337  2014    Ｊ２  第２３節第１日  07/26(土)  18:03  カマタマーレ讃岐       ＦＣ岐阜
#
# ...

# %%
absorp.groupby('stadium')['absorp'].mean().sort_index()#to_csv('./data/absorp4.csv')
# Out:
# stadium
# うまかな・よかなスタジアム                20.175000
# とりぎんバードスタジアム                 22.546429
# エコパスタジアム                     45.432000
# エディオンスタジアム広島                 32.989070
# キンチョウスタジアム                   68.444167
# ケーズデンキスタジアム水戸                36.445370
# シティライトスタジアム                  41.795660
# デンカビッグスワンスタジアム               59.467381
# ニッパツ三ツ沢球技場                   42.703167
# ニンジニアスタジアム                   24.700000
# ノエビアスタジアム神戸                  45.038409
# フクダ電子アリーナ                    51.471481
# ベストアメニティスタジアム                52.031795
# ヤマハスタジアム（磐田）                 67.742045
# ヤンマースタジアム長居                  54.454737
# ユアテックスタジアム仙台                 77.735854
# レベルファイブスタジアム                 24.667407
# 万博記念競技場                      64.047391
# 京都市西京極総合運動公園陸上競技場兼球技場        37.259800
# 佐賀県総合運動場陸上競技場                49.876667
# 北九州市立本城陸上競技場                 32.017778
# 名古屋市瑞穂陸上競技場                  62.538333
# 味の素スタジアム                     29.216456
# 味の素フィールド西が丘                  48.267500
# ...

# %%
69.97
67.665
31.03
49.745
21.805
29.415
68.955
29.54
40.205
58.53
20.58
39.075
22.12
47.225
47.02
65.725
58.885
75.97
25.895
63.665
21.615
48.38
34.63
12.3
45.5
54.245
34.15
54.115
44.965
20.97
31.735
26.55
58.795
28.025
34.485
67.55
14.135
28.39
63.955
28.645
54.765
21.9
